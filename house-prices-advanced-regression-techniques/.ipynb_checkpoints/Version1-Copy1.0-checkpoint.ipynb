# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("train.csv")

# %%
data.head(1)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
#
# [1 rows x 81 columns]

# %%
train=data.drop(["Id","SalePrice"],axis=1)

# %%
target = data["SalePrice"]

# %%
data_type=[]
for col in train.columns:
   data_type.append(train[col].dtype)
data_type=np.unique(data_type)
data_type
# Out:
# array([dtype('int64'), dtype('float64'), dtype('O')], dtype=object)

# %%
#fill missing values in columns which is data type of float64 and int64 
object_value={}
for col in train.columns:
    if train[col].dtype!='O':
        train[col]=train[col].fillna(train[col].mean())
    else:
        tmp=train[col].unique().tolist()
        if np.nan in tmp:
            tmp.remove(np.nan)
        object_value[col]=dict(enumerate(tmp))
                               
object_value
# Out:
# {'Alley': {0: 'Grvl', 1: 'Pave'},
#  'BldgType': {0: '1Fam', 1: '2fmCon', 2: 'Duplex', 3: 'TwnhsE', 4: 'Twnhs'},
#  'BsmtCond': {0: 'TA', 1: 'Gd', 2: 'Fa', 3: 'Po'},
#  'BsmtExposure': {0: 'No', 1: 'Gd', 2: 'Mn', 3: 'Av'},
#  'BsmtFinType1': {0: 'GLQ', 1: 'ALQ', 2: 'Unf', 3: 'Rec', 4: 'BLQ', 5: 'LwQ'},
#  'BsmtFinType2': {0: 'Unf', 1: 'BLQ', 2: 'ALQ', 3: 'Rec', 4: 'LwQ', 5: 'GLQ'},
#  'BsmtQual': {0: 'Gd', 1: 'TA', 2: 'Ex', 3: 'Fa'},
#  'CentralAir': {0: 'Y', 1: 'N'},
#  'Condition1': {0: 'Norm',
#   1: 'Feedr',
#   2: 'PosN',
#   3: 'Artery',
#   4: 'RRAe',
#   5: 'RRNn',
#   6: 'RRAn',
#   7: 'PosA',
#   8: 'RRNe'},
#  'Condition2': {0: 'Norm',
#   1: 'Artery',
#   2: 'RRNn',
#   3: 'Feedr',
#   4: 'PosN',
#   5: 'PosA',
#   6: 'RRAn',
#   7: 'RRAe'},
#  'Electrical': {0: 'SBrkr', 1: 'FuseF', 2: 'FuseA', 3: 'FuseP', 4: 'Mix'},
#  'ExterCond': {0: 'TA', 1: 'Gd', 2: 'Fa', 3: 'Po', 4: 'Ex'},
#  'ExterQual': {0: 'Gd', 1: 'TA', 2: 'Ex', 3: 'Fa'},
#  'Exterior1st': {0: 'VinylSd',
#   1: 'MetalSd',
#   2: 'Wd Sdng',
#   3: 'HdBoard',
#   4: 'BrkFace',
#   5: 'WdShing',
#   6: 'CemntBd',
#   7: 'Plywood',
#   8: 'AsbShng',
#   9: 'Stucco',
#   10: 'BrkComm',
#   11: 'AsphShn',
#   12: 'Stone',
#   13: 'ImStucc',
#   14: 'CBlock'},
#  'Exterior2nd': {0: 'VinylSd',
#   1: 'MetalSd',
#   2: 'Wd Shng',
#   3: 'HdBoard',
#   4: 'Plywood',
#   5: 'Wd Sdng',
#   6: 'CmentBd',
#   7: 'BrkFace',
#   8: 'Stucco',
#   9: 'AsbShng',
#   10: 'Brk Cmn',
#   11: 'ImStucc',
#   12: 'AsphShn',
#   13: 'Stone',
#   14: 'Other',
#   15: 'CBlock'},
#  'Fence': {0: 'MnPrv', 1: 'GdWo', 2: 'GdPrv', 3: 'MnWw'},
#  'FireplaceQu': {0: 'TA', 1: 'Gd', 2: 'Fa', 3: 'Ex', 4: 'Po'},
#  'Foundation': {0: 'PConc',
#   1: 'CBlock',
#   2: 'BrkTil',
#   3: 'Wood',
#   4: 'Slab',
#   5: 'Stone'},
#  'Functional': {0: 'Typ',
#   1: 'Min1',
#   2: 'Maj1',
#   3: 'Min2',
#   4: 'Mod',
#   5: 'Maj2',
#   6: 'Sev'},
#  'GarageCond': {0: 'TA', 1: 'Fa', 2: 'Gd', 3: 'Po', 4: 'Ex'},
#  'GarageFinish': {0: 'RFn', 1: 'Unf', 2: 'Fin'},
#  'GarageQual': {0: 'TA', 1: 'Fa', 2: 'Gd', 3: 'Ex', 4: 'Po'},
#  'GarageType': {0: 'Attchd',
#   1: 'Detchd',
#   2: 'BuiltIn',
#   3: 'CarPort',
#   4: 'Basment',
#   5: '2Types'},
#  'Heating': {0: 'GasA',
#   1: 'GasW',
#   2: 'Grav',
#   3: 'Wall',
#   4: 'OthW',
#   5: 'Floor'},
#  'HeatingQC': {0: 'Ex', 1: 'Gd', 2: 'TA', 3: 'Fa', 4: 'Po'},
#  'HouseStyle': {0: '2Story',
#   1: '1Story',
#   2: '1.5Fin',
#   3: '1.5Unf',
#   4: 'SFoyer',
#   5: 'SLvl',
#   6: '2.5Unf',
#   7: '2.5Fin'},
#  'KitchenQual': {0: 'Gd', 1: 'TA', 2: 'Ex', 3: 'Fa'},
#  'LandContour': {0: 'Lvl', 1: 'Bnk', 2: 'Low', 3: 'HLS'},
#  'LandSlope': {0: 'Gtl', 1: 'Mod', 2: 'Sev'},
#  'LotConfig': {0: 'Inside', 1: 'FR2', 2: 'Corner', 3: 'CulDSac', 4: 'FR3'},
#  'LotShape': {0: 'Reg', 1: 'IR1', 2: 'IR2', 3: 'IR3'},
#  'MSZoning': {0: 'RL', 1: 'RM', 2: 'C (all)', 3: 'FV', 4: 'RH'},
#  'MasVnrType': {0: 'BrkFace', 1: 'None', 2: 'Stone', 3: 'BrkCmn'},
#  'MiscFeature': {0: 'Shed', 1: 'Gar2', 2: 'Othr', 3: 'TenC'},
#  'Neighborhood': {0: 'CollgCr',
#   1: 'Veenker',
#   2: 'Crawfor',
#   3: 'NoRidge',
#   4: 'Mitchel',
#   5: 'Somerst',
#   6: 'NWAmes',
#   7: 'OldTown',
#   8: 'BrkSide',
#   9: 'Sawyer',
#   10: 'NridgHt',
#   11: 'NAmes',
#   12: 'SawyerW',
#   13: 'IDOTRR',
#   14: 'MeadowV',
#   15: 'Edwards',
#   16: 'Timber',
#   17: 'Gilbert',
#   18: 'StoneBr',
#   19: 'ClearCr',
#   20: 'NPkVill',
#   21: 'Blmngtn',
#   22: 'BrDale',
#   23: 'SWISU',
#   24: 'Blueste'},
#  'PavedDrive': {0: 'Y', 1: 'N', 2: 'P'},
#  'PoolQC': {0: 'Ex', 1: 'Fa', 2: 'Gd'},
#  'RoofMatl': {0: 'CompShg',
#   1: 'WdShngl',
#   2: 'Metal',
#   3: 'WdShake',
#   4: 'Membran',
#   5: 'Tar&Grv',
#   6: 'Roll',
#   7: 'ClyTile'},
#  'RoofStyle': {0: 'Gable',
#   1: 'Hip',
#   2: 'Gambrel',
#   3: 'Mansard',
#   4: 'Flat',
#   5: 'Shed'},
#  'SaleCondition': {0: 'Normal',
#   1: 'Abnorml',
#   2: 'Partial',
#   3: 'AdjLand',
#   4: 'Alloca',
#   5: 'Family'},
#  'SaleType': {0: 'WD',
#   1: 'New',
#   2: 'COD',
#   3: 'ConLD',
#   4: 'ConLI',
#   5: 'CWD',
#   6: 'ConLw',
#   7: 'Con',
#   8: 'Oth'},
#  'Street': {0: 'Pave', 1: 'Grvl'},
#  'Utilities': {0: 'AllPub', 1: 'NoSeWa'}}

# %%
for key,lis in object_value.items():
    if train[col].dtype=='O':
        for index,val in lis.items():
            train.loc[train[key]==val,key]=index
        
        print(key)
        train[key]=train[key].fillna(len(lis))
        train[key].astype('int64')
# Out:
# MSZoning
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive
# PoolQC
# Fence
# MiscFeature
# SaleType
# SaleCondition

# %%
for x in train.columns:
    print(x,train[x].dtype)
# Out:
# MSSubClass int64
# MSZoning int64
# LotFrontage float64
# LotArea int64
# Street int64
# Alley int64
# LotShape int64
# LandContour int64
# Utilities int64
# LotConfig int64
# LandSlope int64
# Neighborhood int64
# Condition1 int64
# Condition2 int64
# BldgType int64
# HouseStyle int64
# OverallQual int64
# OverallCond int64
# YearBuilt int64
# YearRemodAdd int64
# RoofStyle int64
# RoofMatl int64
# Exterior1st int64
# Exterior2nd int64
# MasVnrType int64
# MasVnrArea float64
# ExterQual int64
# ExterCond int64
# Foundation int64
# BsmtQual int64
# BsmtCond int64
# BsmtExposure int64
# BsmtFinType1 int64
# BsmtFinSF1 int64
# BsmtFinType2 int64
# BsmtFinSF2 int64
# BsmtUnfSF int64
# TotalBsmtSF int64
# Heating int64
# HeatingQC int64
# CentralAir int64
# Electrical int64
# 1stFlrSF int64
# 2ndFlrSF int64
# LowQualFinSF int64
# GrLivArea int64
# BsmtFullBath int64
# BsmtHalfBath int64
# FullBath int64
# HalfBath int64
# BedroomAbvGr int64
# KitchenAbvGr int64
# KitchenQual int64
# TotRmsAbvGrd int64
# Functional int64
# Fireplaces int64
# FireplaceQu int64
# GarageType int64
# GarageYrBlt float64
# GarageFinish int64
# GarageCars int64
# GarageArea int64
# GarageQual int64
# GarageCond int64
# PavedDrive int64
# WoodDeckSF int64
# OpenPorchSF int64
# EnclosedPorch int64
# 3SsnPorch int64
# ScreenPorch int64
# PoolArea int64
# PoolQC int64
# Fence int64
# MiscFeature int64
# MiscVal int64
# MoSold int64
# YrSold int64
# SaleType int64
# SaleCondition int64

# %%
from sklearn.ensemble import  BaggingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor

clf = {}
clf['Bagging_KNR']= BaggingRegressor(KNeighborsRegressor())
clf['Bagging_DT']= BaggingRegressor(DecisionTreeRegressor())
clf['RandomForest']=RandomForestRegressor()
clf['ExtraTrees']=ExtraTreesRegressor()
clf['AdaBoost']=AdaBoostRegressor()
clf['GradientBoost']=GradientBoostingRegressor()

for key,obj in clf.items():
    scores = cross_val_score(obj, train, target)
    print(key,scores.mean())
    obj.fit(train,target)
# Out:
# Bagging_KNR 0.6490809121664234
# Bagging_DT 0.8265101353842553
# RandomForest 0.840895039905404
# ExtraTrees 0.8294642105446051
# AdaBoost 0.7924533594070119
# GradientBoost 0.8849275398292954

# %%
test=pd.read_csv('test.csv')

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         NaN       0      6    2010        WD         Normal
# 1        Gar2   12500      6    2010        WD         Normal
# 2         NaN       0      3    2010        WD         Normal
# 3         NaN       0      6    2010        WD         Normal
# 4         NaN       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %%
Y=test.drop(["Id"],axis=1);Y.columns.size
# Out:
# 79

# %%
for col in Y.columns:
    if Y[col].dtype!='O':
        Y[col]=Y[col].fillna(Y[col].mean())

# %%
for key,lis in object_value.items():
    if Y[key].dtype=='O':
        tmp=Y[key].unique().tolist()
        
        for index,val in lis.items():
            if val in tmp :
                Y.loc[Y[key]==val,key]=index
                print(key,index,val)


          
        Y[key]=Y[key].fillna(len(lis))
        Y[key].astype('int64')
# Out:
# MSZoning 0 RL
# MSZoning 1 RM
# MSZoning 2 C (all)
# MSZoning 3 FV
# MSZoning 4 RH
# Street 0 Pave
# Street 1 Grvl
# Alley 0 Grvl
# Alley 1 Pave
# LotShape 0 Reg
# LotShape 1 IR1
# LotShape 2 IR2
# LotShape 3 IR3
# LandContour 0 Lvl
# LandContour 1 Bnk
# LandContour 2 Low
# LandContour 3 HLS
# Utilities 0 AllPub
# LotConfig 0 Inside
# LotConfig 1 FR2
# LotConfig 2 Corner
# LotConfig 3 CulDSac
# LotConfig 4 FR3
# LandSlope 0 Gtl
# LandSlope 1 Mod
# LandSlope 2 Sev
# Neighborhood 0 CollgCr
# Neighborhood 1 Veenker
# Neighborhood 2 Crawfor
# Neighborhood 3 NoRidge
# Neighborhood 4 Mitchel
# Neighborhood 5 Somerst
# Neighborhood 6 NWAmes
# Neighborhood 7 OldTown
# Neighborhood 8 BrkSide
# Neighborhood 9 Sawyer
# Neighborhood 10 NridgHt
# Neighborhood 11 NAmes
# Neighborhood 12 SawyerW
# Neighborhood 13 IDOTRR
# Neighborhood 14 MeadowV
# Neighborhood 15 Edwards
# Neighborhood 16 Timber
# Neighborhood 17 Gilbert
# Neighborhood 18 StoneBr
# Neighborhood 19 ClearCr
# Neighborhood 20 NPkVill
# Neighborhood 21 Blmngtn
# Neighborhood 22 BrDale
# Neighborhood 23 SWISU
# Neighborhood 24 Blueste
# Condition1 0 Norm
# Condition1 1 Feedr
# Condition1 2 PosN
# Condition1 3 Artery
# Condition1 4 RRAe
# Condition1 5 RRNn
# Condition1 6 RRAn
# Condition1 7 PosA
# Condition1 8 RRNe
# Condition2 0 Norm
# Condition2 1 Artery
# Condition2 3 Feedr
# Condition2 4 PosN
# Condition2 5 PosA
# BldgType 0 1Fam
# BldgType 1 2fmCon
# BldgType 2 Duplex
# BldgType 3 TwnhsE
# BldgType 4 Twnhs
# HouseStyle 0 2Story
# HouseStyle 1 1Story
# HouseStyle 2 1.5Fin
# HouseStyle 3 1.5Unf
# HouseStyle 4 SFoyer
# HouseStyle 5 SLvl
# HouseStyle 6 2.5Unf
# RoofStyle 0 Gable
# RoofStyle 1 Hip
# RoofStyle 2 Gambrel
# RoofStyle 3 Mansard
# RoofStyle 4 Flat
# RoofStyle 5 Shed
# RoofMatl 0 CompShg
# RoofMatl 1 WdShngl
# RoofMatl 3 WdShake
# RoofMatl 5 Tar&Grv
# Exterior1st 0 VinylSd
# Exterior1st 1 MetalSd
# Exterior1st 2 Wd Sdng
# Exterior1st 3 HdBoard
# Exterior1st 4 BrkFace
# Exterior1st 5 WdShing
# Exterior1st 6 CemntBd
# Exterior1st 7 Plywood
# Exterior1st 8 AsbShng
# Exterior1st 9 Stucco
# Exterior1st 10 BrkComm
# Exterior1st 11 AsphShn
# Exterior1st 14 CBlock
# Exterior2nd 0 VinylSd
# Exterior2nd 1 MetalSd
# Exterior2nd 2 Wd Shng
# Exterior2nd 3 HdBoard
# Exterior2nd 4 Plywood
# Exterior2nd 5 Wd Sdng
# Exterior2nd 6 CmentBd
# Exterior2nd 7 BrkFace
# Exterior2nd 8 Stucco
# Exterior2nd 9 AsbShng
# Exterior2nd 10 Brk Cmn
# Exterior2nd 11 ImStucc
# Exterior2nd 12 AsphShn
# Exterior2nd 13 Stone
# Exterior2nd 15 CBlock
# MasVnrType 0 BrkFace
# MasVnrType 1 None
# MasVnrType 2 Stone
# MasVnrType 3 BrkCmn
# ExterQual 0 Gd
# ExterQual 1 TA
# ExterQual 2 Ex
# ExterQual 3 Fa
# ExterCond 0 TA
# ExterCond 1 Gd
# ExterCond 2 Fa
# ExterCond 3 Po
# ExterCond 4 Ex
# Foundation 0 PConc
# Foundation 1 CBlock
# Foundation 2 BrkTil
# Foundation 3 Wood
# Foundation 4 Slab
# Foundation 5 Stone
# BsmtQual 0 Gd
# BsmtQual 1 TA
# BsmtQual 2 Ex
# BsmtQual 3 Fa
# BsmtCond 0 TA
# BsmtCond 1 Gd
# BsmtCond 2 Fa
# BsmtCond 3 Po
# BsmtExposure 0 No
# BsmtExposure 1 Gd
# BsmtExposure 2 Mn
# BsmtExposure 3 Av
# BsmtFinType1 0 GLQ
# BsmtFinType1 1 ALQ
# BsmtFinType1 2 Unf
# BsmtFinType1 3 Rec
# BsmtFinType1 4 BLQ
# BsmtFinType1 5 LwQ
# BsmtFinType2 0 Unf
# BsmtFinType2 1 BLQ
# BsmtFinType2 2 ALQ
# BsmtFinType2 3 Rec
# BsmtFinType2 4 LwQ
# BsmtFinType2 5 GLQ
# Heating 0 GasA
# Heating 1 GasW
# Heating 2 Grav
# Heating 3 Wall
# HeatingQC 0 Ex
# HeatingQC 1 Gd
# HeatingQC 2 TA
# HeatingQC 3 Fa
# HeatingQC 4 Po
# CentralAir 0 Y
# CentralAir 1 N
# Electrical 0 SBrkr
# Electrical 1 FuseF
# Electrical 2 FuseA
# Electrical 3 FuseP
# KitchenQual 0 Gd
# KitchenQual 1 TA
# KitchenQual 2 Ex
# KitchenQual 3 Fa
# Functional 0 Typ
# Functional 1 Min1
# Functional 2 Maj1
# Functional 3 Min2
# Functional 4 Mod
# Functional 5 Maj2
# Functional 6 Sev
# FireplaceQu 0 TA
# FireplaceQu 1 Gd
# FireplaceQu 2 Fa
# FireplaceQu 3 Ex
# FireplaceQu 4 Po
# GarageType 0 Attchd
# GarageType 1 Detchd
# GarageType 2 BuiltIn
# GarageType 3 CarPort
# GarageType 4 Basment
# GarageType 5 2Types
# GarageFinish 0 RFn
# GarageFinish 1 Unf
# GarageFinish 2 Fin
# GarageQual 0 TA
# GarageQual 1 Fa
# GarageQual 2 Gd
# GarageQual 4 Po
# GarageCond 0 TA
# GarageCond 1 Fa
# GarageCond 2 Gd
# GarageCond 3 Po
# GarageCond 4 Ex
# PavedDrive 0 Y
# PavedDrive 1 N
# PavedDrive 2 P
# PoolQC 0 Ex
# PoolQC 2 Gd
# Fence 0 MnPrv
# Fence 1 GdWo
# Fence 2 GdPrv
# Fence 3 MnWw
# MiscFeature 0 Shed
# MiscFeature 1 Gar2
# MiscFeature 2 Othr
# SaleType 0 WD
# SaleType 1 New
# SaleType 2 COD
# SaleType 3 ConLD
# SaleType 4 ConLI
# SaleType 5 CWD
# SaleType 6 ConLw
# SaleType 7 Con
# SaleType 8 Oth
# SaleCondition 0 Normal
# SaleCondition 1 Abnorml
# SaleCondition 2 Partial
# SaleCondition 3 AdjLand
# SaleCondition 4 Alloca
# SaleCondition 5 Family

# %%
sub=clf['GradientBoost'].predict(Y)
#sub=clf['AdaBoost'].predict(Y)

#clf['RandomForest']=RandomForestRegressor()
#clf['ExtraTrees']=ExtraTreesRegressor()
#clf['AdaBoost']=AdaBoostRegressor()

# %%
submission=pd.DataFrame(sub,columns=['SalePrice'])

# %%
submission['Id']=test['Id']

# %%
submission.head()
# Out:
#        SalePrice    Id
# 0  121131.045654  1461
# 1  160403.774171  1462
# 2  179679.982344  1463
# 3  182339.435913  1464
# 4  195522.120199  1465

# %%
submission=submission[['Id','SalePrice']]

# %%
submission.to_csv("submission.csv",index=False)
